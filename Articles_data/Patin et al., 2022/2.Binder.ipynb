# %%
# %load_ext autoreload
# %autoreload 2

import Binder
from glob import glob
import pandas as pd
# Out:
# /home/gus/anaconda3/lib/python3.8/site-packages/colour/utilities/verbose.py:237: ColourUsageWarning: "colour.models.XYZ_to_colourspace_model" object is deprecated and will be removed in a future release.
#   warn(*args, **kwargs)

# %%
Binder.MFT(sample = 'BW1', lamp = 'HPX')
# Out:
# /home/gus/anaconda3/lib/python3.8/site-packages/colour/utilities/verbose.py:237: ColourUsageWarning: "colour.models.XYZ_to_colourspace_model" object is deprecated and will be removed in a future release.
#   warn(*args, **kwargs)
# ...

# %%
sample = 'BW1'
lamp = 'HPX'
file_SP = glob(f'*{sample}*{lamp}*dE*')[0]

df_SP = pd.read_csv(file_SP, header = [0,1])
E_pho = df_SP['cum_klux_hr', 'value'].values.astype(int)
E_pho
# Out:
# array([   0,   33,   67,  101,  135,  168,  202,  236,  270,  303,  337,
#         371,  405,  438,  472,  506,  540,  574,  607,  641,  675,  709,
#         742,  776,  810,  844,  877,  911,  945,  979, 1013, 1046, 1080,
#        1114, 1148, 1181, 1215, 1249, 1283, 1316])

# %%
df_SP
# Out:
#    time_s cum_MJ/m2  cum_klux_hr      dE76                dE00            \
#     value     value        value      mean       std      mean       std
# 0     0.0      0.00     0.000000  0.000000  0.000000  0.000000  0.000000
# 1    15.0      0.45    33.766883  1.110000  0.037417  0.426667  0.016997
# 2    30.0      0.90    67.533767  1.880000  0.058878  0.726667  0.023570
# 3    45.0      1.35   101.300650  2.513333  0.089567  0.980000  0.029439
# 4    60.0      1.80   135.067533  3.056667  0.111455  1.203333  0.040277
# 5    75.0      2.25   168.834417  3.500000  0.141657  1.386667  0.052493
# 6    90.0      2.70   202.601300  3.913333  0.164384  1.570000  0.063770
# 7   105.0      3.15   236.368183  4.283333  0.172498  1.726667  0.065997
# 8   120.0      3.60   270.135067  4.616667  0.188031  1.873333  0.075865
# 9   135.0      4.05   303.901950  4.923333  0.187853  2.013333  0.075865
# 10  150.0      4.50   337.668833  5.210000  0.187794  2.143333  0.083400
# ...
